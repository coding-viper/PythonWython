# %%
age = 18
Class = "primary"

# %%
age >= 18
# Out:
# True

# %%
Class == "primary"
# Out:
# True

# %%
## and , or
## and => c1 and c2 and c3 and c4 and c5 ... => result will be True only if all conditions eval to True ( and => all)
## or => c1 or c2 or c3 or c4 or c5 ... =>  result will be True only if at least one conditions eval to True ( or => one )

# %%
age >= 18 and Class == "primary"
# Out:
# True

# %%
age = 16

# %%
age >= 18 and Class == "primary"
# Out:
# False

# %%
age = 21
if age >= 18 and Class == "primary":
  print("Sending mail for advertisement.....")
# Out:
# Sending mail for advertisement.....

# %%
###
monthly_statement = 120000

# %%
employee_type = "permanent"

# %%
employee_type = "permanent"
monthly_statement = 170000
Class = "basic"

# %%
if employee_type != "vendor":
  if monthly_statement > 150000 or Class == "primary" :
    print("Sending mail for advertisement.....")
# Out:
# Sending mail for advertisement.....

# %%
a = 123

# %%
a is int
# Out:
# False

# %%
a is 123
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-26-41aa1855dafc>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   a is 123
# True

# %%
type(a) is int
# Out:
# True

# %%
a = 13.4
type(a) is not float
# Out:
# False

# %%
## truthy and falsy

# %%
"Tushar" or ""
# Out:
# 'Tushar'

# %%
"" or "Tushar"
# Out:
# 'Tushar'

# %%
0 or 123
# Out:
# 123

# %%
"" or 0 or "Tushar"
# Out:
# 'Tushar'

# %%
"" or 0 or "Tushar" or "Yash" or "Shubham" or 1343 #the first truthy value
# Out:
# 'Tushar'

# %%
"" and "Tushar"  # first falsy , last truthy value
# Out:
# ''

# %%
"Tushar" and ""
# Out:
# ''

# %%
"Tushar" and "samar" and "sagar" and "kamal"
# Out:
# 'kamal'

# %%
"Tushar" and "samar" and 0 and "kamal" and ""
# Out:
# 0

# %%
# 4 servers. 101, 102, 103, 104
s1 = 0
s2 = 0
s3 = 0
s4 = 5
s1 or s2 or s3 or s4
# Out:
# 5

# %%
## bitwise operator => & | << >>

# %%
1 & 2
# Out:
# 0

# %%
print(bin(1))
print(bin(2))
# 001
# 010
# Out:
# 0b1
# 0b10

# %%
3 & 5
# Out:
# 1

# %%
# 011
# 101
# 001

# %%
1 | 2
# Out:
# 3

# %%
# 001
# 010
# 011
bin(3)
# Out:
# '0b11'

# %%
3 | 5
# Out:
# 7

# %%
# 011
# 101
# 111
bin(7)
# Out:
# '0b111'

# %%
5 << 1
# 1010
# 1010
# Out:
# 10

# %%
3 << 1
# 0110
bin(6)
# Out:
# '0b110'

# %%
print(5 >> 1)
# 101|
# 10|1
bin(2)
# Out:
# 2
# '0b10'

# %%
print(15 >> 4)
# 1111|
# |1111
# Out:
# 0

# %%
15 << 1
# Out:
# 30

# %%
2 << 2
# Out:
# 8

# %%
# left shifty => larger
# right shifty => smaller

# %%
## control statements

# %%
## if

# %%
budget = 30000
price = 20000
if budget >= price:
  print("GO buy it.")
# Out:
# GO buy it.

# %%
print(input.__doc__)
# Out:
# Forward raw_input to frontends
#
#         Raises
#         ------
#         StdinNotImplementedError if active frontend doesn't support stdin.

# %%
budget = input()
print(budget)
print(type(budget))
if budget >= price:
  print("GO buy it.")
# Out:
# 10000
# 10000
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-a8733283e423> in <cell line: 4>()
#       2 print(budget)
#       3 print(type(budget))
# ----> 4 if budget >= price:
#       5   print("GO buy it.")
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
budget = int(input())
print(budget)
print(type(budget))
if budget >= price:
  print("GO buy it.")
# Out:
# 30000
# 30000
# <class 'int'>
# GO buy it.

# %%
budget = float(input())
print(budget)
print(type(budget))
if budget > price:
  print("GO buy it.")
# Out:
# 20000
# 20000.0
# <class 'float'>

# %%
budget = eval(input())
print(budget)
print(type(budget))
if budget >= price:
  print("GO buy it.")
# Out:
# uytutt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-f2dc2999ed93> in <cell line: 1>()
# ----> 1 budget = eval(input())
#       2 print(budget)
#       3 print(type(budget))
#       4 if budget >= price:
#       5   print("GO buy it.")
#
# <string> in <module>
#
# NameError: name 'uytutt' is not defined

# %%
print(eval.__doc__)
# Out:
# Evaluate the given source in the context of globals and locals.
#
# The source may be a string representing a Python expression
# or a code object as returned by compile().
# The globals must be a dictionary and locals can be any mapping,
# defaulting to the current globals and locals.
# If only globals is given, locals defaults to it.

# %%
123
# Out:
# 123

# %%
123.45
# Out:
# 123.45

# %%
print('Hello')
# Out:
# Hello

# %%
a = 123
b = 123.45

# %%
a = eval(input())
# 123 => "123" => 123
# Out:
# 123

# %%
a
# Out:
# 123

# %%
b = eval(input())
# 123.45 => "123.45" =>b = 123.45
# Out:
# 123.45

# %%
b
# Out:
# 123.45

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
un = input("Enter user name :")
# Out:
# Enter user name :coding viper

# %%
un
# Out:
# 'coding viper'
