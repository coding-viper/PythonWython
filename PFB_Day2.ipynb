# %%
# int, float, string, complex => python

# %%
a = 123

# %%
type(a)
# Out:
# int

# %%
a.bit_length()
# Out:
# 7

# %%
bin(a)
# Out:
# '0b1111011'

# %%
a.bit_count()
# Out:
# 6

# %%
## 1. PYthon off docs, help(), __doc__

# %%
print(int.__doc__)
# Out:
# int([x]) -> integer
# int(x, base=10) -> integer
#
# Convert a number or string to an integer, or return 0 if no arguments
# are given.  If x is a number, return x.__int__().  For floating point
# numbers, this truncates towards zero.
#
# If x is not a number or if base is given, then x must be a string,
# bytes, or bytearray instance representing an integer literal in the
# given base.  The literal can be preceded by '+' or '-' and be surrounded
# by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
# Base 0 means to interpret the base from the string as an integer literal.
# >>> int('0b100', base=0)
# 4

# %%
a = int(123)

# %%
int('123')
# Out:
# 123

# %%
int()
# Out:
# 0

# %%
# 0-9, a,b ,c , d, e , f

# %%
a = int('17',base = 16 )

# %%
print(a)
# Out:
# 23

# %%
## complex

# %%
a = 12 + 4j

# %%
a
# Out:
# (12+4j)

# %%
type(a)
# Out:
# complex

# %%
a.real
# Out:
# 12.0

# %%
a.imag
# Out:
# 4.0

# %%
a.conjugate()

## 12+4j * 12- 4j   144 - 16(-1) 144 + 16
# Out:
# (12-4j)

# %%
## operations

# %%
## arithmetic

# %%
123 + 123.3434
# Out:
# 246.3434

# %%
123 - 12.843
# Out:
# 110.157

# %%
12 * 12
# Out:
# 144

# %%
123 - 12
# Out:
# 111

# %%
12 / 3
# floating division
# Out:
# 4.0

# %%
12 // 3
## integral ( takes q forgets remainder)
# Out:
# 4

# %%
12 / 5
# Out:
# 2.4

# %%
12 // 5
# Out:
# 2

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
0.1 + 0.1 + 0.1
# Out:
# 0.30000000000000004

# %%
a = 0.1
a.as_integer_ratio()
# Out:
# (3602879701896397, 36028797018963968)

# %%
12 ** 2
# Out:
# 144

# %%
12 ** 2.5
# Out:
# 498.8306325798367

# %%
12.0 ** 2
# Out:
# 144.0

# %%
9.0 * 8.0
# Out:
# 72.0

# %%
12 % 5
# Out:
# 2

# %%
121 % 2
# Out:
# 1

# %%
12 % 6
# Out:
# 0

# %%
a = 123
a = 1+ a
print(a)
# Out:
# 124

# %%
123.45 % 3
# Out:
# 0.45000000000000284

# %%
fn = 'tushar'
ln = 'tripathi'

# %%
fn +" " +ln
# Out:
# 'tushar tripathi'

# %%
fn + '10'
# Out:
# 'tushar10'

# %%
fn * 3
# Out:
# 'tushartushartushar'

# %%
fn * '3'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-d4d87fcdfa88> in <cell line: 1>()
# ----> 1 fn * '3'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
fn - 'tush'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-c9a4f322c66e> in <cell line: 1>()
# ----> 1 fn - 'tush'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
## logical

# %%
12 > 13
# Out:
# False

# %%
12 == 13
# Out:
# False

# %%
12 < 13
# Out:
# True

# %%
12 <= 13
# Out:
# True

# %%
12 >= 13
# Out:
# False

# %%
13 >= 13
# Out:
# True

# %%
'a' > 'b'
# Out:
# False

# %%
'a' > 'A'
ord('A')
# Out:
# 65

# %%
'TUSHAR' > 'tushar'
# Out:
# False

# %%
'TUSHAR' > 'Tushar'
# Out:
# False

# %%
'TUshar' > 'TUthar'
# Out:
# False

# %%
123 == 123
# Out:
# True

# %%
123 == '123'
# Out:
# False

# %%
camera = "NO"
mic = 'YES'

# %%
if camera != "NO":
  print("calling webcam drivers.....")

# %%
state = 'pending'
if state != "closed":
  print("do next steps.....")
# Out:
# do next steps.....
