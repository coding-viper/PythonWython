# %%
# set => mutable, unordered, unique object collection

# %%
s = set()

# %%
s
# Out:
# set()

# %%
type(s)
# Out:
# set

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s
# Out:
# {}

# %%
s = {1,2,3,4,4,4,4,4,34,4,3,3,3,3}

# %%
type(s)
# Out:
# set

# %%
s
# Out:
# {1, 2, 3, 4, 34}

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c9c96910e542> in <cell line: 1>()
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
list_set = list(s)

# %%
list_set
# Out:
# [1, 2, 3, 4, 34]

# %%
s
# Out:
# {1, 2, 3, 4, 34}

# %%
list_set[0]
# Out:
# 1

# %%
list_set[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-5154d92dce5b> in <cell line: 1>()
# ----> 1 list_set[5]
#
# IndexError: list index out of range

# %%
s = {0,3,6,9,12,15,18,21}

# %%
t = {0,5,10,15,20,25,30,35,40}

# %%
s.difference(t)
# Out:
# {3, 6, 9, 12, 18, 21}

# %%
s
# Out:
# {0, 3, 6, 9, 12, 15, 18, 21}

# %%
s.difference_update(t)

# %%
s
# Out:
# {3, 6, 9, 12, 18, 21}

# %%
s = {0,3,6,9,12,15,18,21}

# %%
s.intersection(t)
# Out:
# {0, 15}

# %%
s.intersection_update(t)

# %%
s
# Out:
# {0, 15}

# %%
s.issubset(t)
# Out:
# True

# %%
s
# Out:
# {0, 15}

# %%
t
# Out:
# {0, 5, 10, 15, 20, 25, 30, 35, 40}

# %%
s.add(33)

# %%
s
# Out:
# {0, 15, 33}

# %%
s.issubset(t)
# Out:
# False

# %%
s.issuperset(t)
# Out:
# False

# %%
s.intersection_update(t)

# %%
s
# Out:
# {0, 15}

# %%
t
# Out:
# {0, 5, 10, 15, 20, 25, 30, 35, 40}

# %%
t.issuperset(s)
# Out:
# True

# %%
s.isdisjoint(t)
# Out:
# False

# %%
s = {1,2,3}

# %%
s.isdisjoint(t)
# Out:
# True

# %%
s.symmetric_difference(t)

# %%
s = {0, 15, 33}

# %%
t
# Out:
# {0, 5, 10, 15, 20, 25, 30, 35, 40}

# %%
s.symmetric_difference(t)
# Out:
# {5, 10, 20, 25, 30, 33, 35, 40}

# %%
t.symmetric_difference(s)
# Out:
# {5, 10, 20, 25, 30, 33, 35, 40}

# %%
s.difference(t)
# Out:
# {33}

# %%
t.difference(s)
# Out:
# {5, 10, 20, 25, 30, 35, 40}

# %%
var = t.symmetric_difference_update(s)

# %%
var == None
# Out:
# True

# %%
s.pop()
# Out:
# 15

# %%
s.pop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-c88c8c48122b> in <cell line: 1>()
# ----> 1 s.pop()
#
# KeyError: 'pop from an empty set'

# %%
s = {1,2,3}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
t = s.copy()

# %%
id(s), id(t)
# Out:
# (134952716628736, 134952716630528)

# %%
t = s

# %%
id(s), id(t)
# Out:
# (134952716628736, 134952716628736)
